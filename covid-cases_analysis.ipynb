# %%
import matplotlib as plt
import numpy as np
import pandas as pd

# %%
covid_data = pd.read_csv('covid-cases.csv')

# %%
covid_data.head(20)
# Out:
#     S/N ObservationDate Province/State Country/Region Last Update  Confirmed  \
# 0     1      25/08/2021         Kigali         Rwanda  25/08/2021        555
# 1     2      25/08/2022      Cape Town   South Africa  25/08/2022       2250
# 2     3      25/08/2023        Nairobi          Kenya  25/08/2023       1800
# 3     4      25/08/2024  Washington DC            USA  25/08/2024       5430
# 4     5      25/08/2025         Berlin        Germany  25/08/2025       2000
# 5     6      25/08/2026       Brussels        Belgium  25/08/2026       2100
# 6     7      25/08/2027        Beijing          China  25/08/2027      12000
# 7     8      25/08/2028   Addis-Ababas       Ethiopia  25/08/2028        890
# 8     9      25/08/2029           Rome          Italy  25/08/2029       4000
# 9    10      25/08/2030          Paris         France  25/08/2030       5000
# 10   11      25/08/2031         London             UK  25/08/2031       8090
# ...
